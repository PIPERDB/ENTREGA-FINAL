# %%
#Importo librerias necesarias para el desafío.
import json
import requests
import pandas as pd

# %%
#Url de la api, datos del gobierno de colombia, sobra accidentes de transito desde el 2010 al 2016.
URL = 'https://www.datos.gov.co/resource/6y9g-d9u8.json'

# %%
#Hago la petición de información.
df = requests.get(URL)
print(df)
# Out:
# <Response [200]>

# %%
df.text
# Out:
# '[{"cod_dpto":"17","cod_munic":"1","a_defun":"1","sit_defun":"1","cod_inst":"170010010301","nom_inst":"SERVICIOS ESPECIALES DE SALUD","tipo_defun":"2","fecha_def":"2010-01-14T00:00:00.000","ano":"2010","mes":"1","hora":"1","minutos":"58","sexo":"2","fecha_nac":"1946-03-27T00:00:00.000","est_civil":"6","edad":"4063","nivel_edu":"99","ultcurfal":"99","muerteporo":"2","idpertet":"6","idpuebin":"0","codptore":"17","codmunre":"1","area_res":"1","barriofal":"COMUNEROS","seg_social":"2","idadmisalu":"2","idclasadmi":"CALISALUD - ENTIDAD PROMOTORA DE SALUD","pman_muer":"2","cons_exp":"3","peso_nac":"0","edad_madre":"0","n_hijosv":"0","n_hijosm":"0","ultcurmad":"0","man_muer":"3","comocuhec":"PEATON ATROPELLADO POR VEHICULO","codocur":"17","codmunoc":"1","dirocuhec":"AV DEL RIO FRENTE A  DIAGNOSTICENTR","localocuhe":"5090","c_muerte":"1","asis_med":"1","n_dir1":"CHOQUE HIPOVOLEMICO","c_dir1":"T794","n_ant1":"FRACTURAS MULTIPLES","c_ant1":"T029","n_ant2":"TRAUMA  EN HECHOS RELACIONADOS CON TRA
# ...

# %%
#Convierto el texto plano en json.
texto = df.text
jsondata = json.loads(texto)
json.loads(texto)
# Out:
# [{'cod_dpto': '17',
#   'cod_munic': '1',
#   'a_defun': '1',
#   'sit_defun': '1',
#   'cod_inst': '170010010301',
#   'nom_inst': 'SERVICIOS ESPECIALES DE SALUD',
#   'tipo_defun': '2',
#   'fecha_def': '2010-01-14T00:00:00.000',
#   'ano': '2010',
#   'mes': '1',
#   'hora': '1',
#   'minutos': '58',
#   'sexo': '2',
#   'fecha_nac': '1946-03-27T00:00:00.000',
#   'est_civil': '6',
#   'edad': '4063',
#   'nivel_edu': '99',
#   'ultcurfal': '99',
#   'muerteporo': '2',
#   'idpertet': '6',
#   'idpuebin': '0',
#   'codptore': '17',
#   'codmunre': '1',
#   'area_res': '1',
#   'barriofal': 'COMUNEROS',
#   'seg_social': '2',
#   'idadmisalu': '2',
#   'idclasadmi': 'CALISALUD - ENTIDAD PROMOTORA DE SALUD',
#   'pman_muer': '2',
#   'cons_exp': '3',
#   'peso_nac': '0',
#   'edad_madre': '0',
#   'n_hijosv': '0',
#   'n_hijosm': '0',
#   'ultcurmad': '0',
#   'man_muer': '3',
#   'comocuhec': 'PEATON ATROPELLADO POR VEHICULO',
#   'codocur': '17',
#   'codmunoc': '1',
# ...
